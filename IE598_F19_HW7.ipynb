# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.model_selection import train_test_split

data = pd.read_csv(r"C:\Users\jazoi\Downloads\ccdefault.csv")
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0        1
# ...

# %%
#Prints total nunmber of rows and columns in the dataset
#Confirmed correct by manual check of the dataset .csv file
#Recycled from my personal HW3 assignment
#Prints total nunmber of rows and columns in the dataset
#Confirmed correct by manual check of the dataset .csv file
#Reused from my personal HW3 assignment

total_rows=len(data.axes[0])
total_cols=len(data.axes[1])
print("Number of Rows: "+ str(total_rows))
print("Number of Columns: "+ str(total_cols))
print()
data.shape
# Out:
# Number of Rows: 30000
# Number of Columns: 25
# (30000, 25)

# %%
data.info()
#No data needs to be dropped!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID           30000 non-null int64
# LIMIT_BAL    30000 non-null int64
# SEX          30000 non-null int64
# EDUCATION    30000 non-null int64
# MARRIAGE     30000 non-null int64
# AGE          30000 non-null int64
# PAY_0        30000 non-null int64
# PAY_2        30000 non-null int64
# PAY_3        30000 non-null int64
# PAY_4        30000 non-null int64
# PAY_5        30000 non-null int64
# PAY_6        30000 non-null int64
# BILL_AMT1    30000 non-null int64
# BILL_AMT2    30000 non-null int64
# BILL_AMT3    30000 non-null int64
# BILL_AMT4    30000 non-null int64
# BILL_AMT5    30000 non-null int64
# BILL_AMT6    30000 non-null int64
# PAY_AMT1     30000 non-null int64
# PAY_AMT2     30000 non-null int64
# PAY_AMT3     30000 non-null int64
# PAY_AMT4     30000 non-null int64
# PAY_AMT5     30000 non-null int64
# PAY_AMT6     30000 non-null int64
# ...

# %%
#PART ONE
import time

y = data.iloc[:,24]
X = data.iloc[:, 1:-1]

start = time.clock()

clf = RandomForestClassifier(n_estimators = 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 1)

cv_scores_train = cross_val_score(clf, X_train, y_train, cv=10)
cv_scores_test = cross_val_score(clf, X_test, y_test, cv=10)

CV_accuracyScore_DF = pd.DataFrame(
    {
        'CV Fold': range(10),
        'In-sample Score': cv_scores_train,
    })

end = time.clock()
print('Amount of time to run: ', end - start, 'seconds')


CV_accuracyScore_DF.head(10)
# Out:
# C:\Users\jazoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   import sys
# Amount of time to run:  0.696300000001429 seconds
# C:\Users\jazoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#    CV Fold  In-sample Score
# 0        0         0.710000
# 1        1         0.726296
# 2        2         0.731481
# 3        3         0.722593
# 4        4         0.708519
# 5        5         0.735185
# 6        6         0.709630
# 7        7         0.710741
# 8        8         0.731481
# 9        9         0.722963

# %%
start = time.clock()

clf2 = RandomForestClassifier(n_estimators = 2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 2)

cv_scores_train = cross_val_score(clf2, X_train, y_train, cv=10)
cv_scores_test = cross_val_score(clf2, X_test, y_test, cv=10)

CV_accuracyScore_DF = pd.DataFrame(
    {
        'CV Fold': range(10),
        'In-sample Score': cv_scores_train,
    })

end = time.clock()
print('Amount of time to run: ', end - start, 'seconds')


CV_accuracyScore_DF.head(10)
# Out:
# C:\Users\jazoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.
# Amount of time to run:  1.257801699999618 seconds
# C:\Users\jazoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   from ipykernel import kernelapp as app
#    CV Fold  In-sample Score
# 0        0         0.775268
# 1        1         0.780822
# 2        2         0.785265
# 3        3         0.796372
# 4        4         0.783043
# 5        5         0.781771
# 6        6         0.786217
# 7        7         0.791775
# 8        8         0.776213
# 9        9         0.783624

# %%
start = time.clock()

clf3 = RandomForestClassifier(n_estimators = 3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 3)

cv_scores_train = cross_val_score(clf3, X_train, y_train, cv=10)
cv_scores_test = cross_val_score(clf3, X_test, y_test, cv=10)

CV_accuracyScore_DF = pd.DataFrame(
    {
        'CV Fold': range(10),
        'In-sample Score': cv_scores_train,
    })

end = time.clock()
print('Amount of time to run: ', end - start, 'seconds')


CV_accuracyScore_DF.head(10)
# Out:
# C:\Users\jazoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.
# Amount of time to run:  1.805285799999183 seconds
# C:\Users\jazoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   from ipykernel import kernelapp as app
#    CV Fold  In-sample Score
# 0        0         0.759719
# 1        1         0.771196
# 2        2         0.767494
# 3        3         0.767864
# 4        4         0.763333
# 5        5         0.766667
# 6        6         0.768433
# 7        7         0.769544
# 8        8         0.769915
# 9        9         0.781771

# %%
start = time.clock()

clf4 = RandomForestClassifier(n_estimators = 4)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 4)

cv_scores_train = cross_val_score(clf4, X_train, y_train, cv=10)
cv_scores_test = cross_val_score(clf4, X_test, y_test, cv=10)

CV_accuracyScore_DF = pd.DataFrame(
    {
        'CV Fold': range(10),
        'In-sample Score': cv_scores_train,
    })

end = time.clock()
print('Amount of time to run: ', end - start, 'seconds')


CV_accuracyScore_DF.head(10)
# Out:
# C:\Users\jazoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.
# Amount of time to run:  2.373353799999677 seconds
# C:\Users\jazoi\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   from ipykernel import kernelapp as app
#    CV Fold  In-sample Score
# 0        0         0.802295
# 1        1         0.788597
# 2        2         0.797407
# 3        3         0.805926
# 4        4         0.793333
# 5        5         0.789630
# 6        6         0.798148
# 7        7         0.792593
# 8        8         0.799555
# 9        9         0.794368

# %%
# PART TWO
# Assistance from class text, DataCamp, and https://www.programcreek.com/python/example/93976/sklearn.feature_selection.SelectFromModel

from matplotlib import pyplot as plt

feat_labels = data.columns[1:]

clf4.fit(X_train, y_train)
importances = clf4.feature_importances_

indices = np.argsort(importances)[::-1]

for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, feat_labels[indices[f]], importances[indices[f]]))
plt.title('Feature Importance')
plt.bar(range(X_train.shape[1]), importances[indices], align='center')

plt.xticks(range(X_train.shape[1]),
    feat_labels[indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.tight_layout()
plt.show()
# Out:
#  1) PAY_0                          0.076397
#  2) PAY_2                          0.071066
#  3) AGE                            0.063762
#  4) LIMIT_BAL                      0.061476
#  5) BILL_AMT1                      0.056441
#  6) PAY_AMT2                       0.054101
#  7) BILL_AMT2                      0.053271
#  8) BILL_AMT3                      0.053201
#  9) BILL_AMT4                      0.049748
# 10) BILL_AMT6                      0.049706
# 11) BILL_AMT5                      0.048295
# 12) PAY_AMT1                       0.048237
# 13) PAY_AMT6                       0.047569
# 14) PAY_AMT3                       0.046031
# 15) PAY_AMT5                       0.044360
# 16) PAY_AMT4                       0.043483
# 17) PAY_3                          0.041682
# 18) EDUCATION                      0.023491
# 19) PAY_5                          0.017564
# 20) PAY_6                          0.015312
# 21) MARRIAGE                       0.014587
# ...

# %%
# Assistance from DataCamp and https://www.programcreek.com/python/example/93976/sklearn.feature_selection.SelectFromModel

from sklearn.feature_selection import SelectFromModel

sfm = SelectFromModel(clf4, threshold=0.05, prefit=True)
X_selected = sfm.transform(X_train)
print('Number of features that meet this threshold criterion:', X_selected.shape[1])

for f in range(X_selected.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, feat_labels[indices[f]], importances[indices[f]]))
# Out:
# Number of features that meet this threshold criterion: 8
#  1) PAY_0                          0.076397
#  2) PAY_2                          0.071066
#  3) AGE                            0.063762
#  4) LIMIT_BAL                      0.061476
#  5) BILL_AMT1                      0.056441
#  6) PAY_AMT2                       0.054101
#  7) BILL_AMT2                      0.053271
#  8) BILL_AMT3                      0.053201

# %%
print("My name is Jonathan Zoia")
print("My NetID is: jzoia2")
print("I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.")
# Out:
# My name is Jonathan Zoia
# My NetID is: jzoia2
# I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.
